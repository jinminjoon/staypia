# %%
import pymysql
from sqlalchemy import create_engine

import pandas as pd
import time
import os

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager 
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
from tqdm import tqdm
from selenium.webdriver.common.by import By

import datetime

# %% [markdown]
# # 1.엑셀에서 검색할 도시 정보 불러오기

# %%
Desktop = os.path.dirname(os.getcwd())
Desktop
# Out:
# '/Users/mycelebs/Desktop/staypia_데이터수집'

# %%
file_path=f'{Desktop}/data/staypia_bucketlist_v2.xlsx'
data = pd.read_excel(file_path)
data
# Out:
#       cd_idx                                            bd_name  \
# 0    3193035  Take a walk in Harry Potter's magician street,...
# 1    3193036  Explore the American Museum of Natural History...
# 2    3193037  Take a walk to Kualoa Ranch, the primitive env...
# 3    3193038  Relax by yourself in luxury and antique Plaza ...
# 4    3193039  Read books in a romantic city of literature, N...
# ..       ...                                                ...
# 725  3664671  Sakte at the ‘Wollman Rink’, the ice-rink in t...
# 726  3664673   Relax at the temple of happiness 'Punakha Dzong’
# 727  3664679  Feel the thrill of crossing the sky! Ride an a...
# 728  3664680  Take a picture at ‘Sirao Garden’, the beautifu...
# 729        ↵  판단 잎으로 만드는 달콤함과 고소함의 결정체, 카야잼을 아시나요? 싱가포르의 '야쿤...
#
#                                      bd_name_ko  relation_cd_idx  \
# 0                <해리포터>의 마법사 거리, '다이애건 앨리' 걸어보기        1213719.0
# 1         인류와 생물 그리고 우주에 관하여, 뉴욕 '자연사 박물관' 탐방하기        1228306.0
# 2                 원시 자연의 모습 그대로, '쿠알로아 랜치' 산책하기        1218193.0
# 3    100년의 역사를 간직한 호화로운 '플라자 호텔'에서 나 홀로 호캉스 즐기기        1228306.0
# 4                   로맨틱한 문학 도시 '노팅힐'의 서점에서 독서하기        1213719.0
# ..                                          ...              ...
# 725                빌딩 숲속의 빙판, '울먼 링크'에서 스케이트 타기        1228306.0
# 726          행복을 전하는 사원, 'Punakha Dzong'에서 힐링하기        3132116.0
# 727      하늘을 가로지르는 짜릿함! '핑동 어드벤처 플라이트'에서 항공기 타기        1213328.0
# 728                아름다운 하늘 정원, '시라오 가든'에서 사진 찍기        1215658.0
# 729                                         NaN              NaN
#
#     related_vertical_name bd_category  ko_youtube
# 0                      런던      TRAVEL           1
# 1                      뉴욕      TRAVEL           1
# 2                    호놀룰루      TRAVEL           1
# 3                      뉴욕      TRAVEL           1
# 4                      런던      TRAVEL           1
# ..                    ...         ...         ...
# 725                    뉴욕     OUTDOOR           0
# 726                   푸나카     CULTURE           0
# 727                    켄팅     OUTDOOR           0
# 728                    세부      TRAVEL           0
# 729                   NaN         NaN           0
#
# [730 rows x 7 columns]

# %% [markdown]
# # 2.데이터 크롤링 시작

# %%
options = webdriver.ChromeOptions()
#options.add_argument('headless')
options.add_argument('--incognito')
prefs = {'intl.accept_languages': 'en,en_US','cookies': 2, 'images': 1, 'plugins': 2, 'popups': 2,
                                                    'geolocation': 2, 'notifications': 2,
                                                    'auto_select_certificate': 2, 'fullscreen': 2, 'mouselock': 2,
                                                    'mixed_script': 2, 'media_stream': 2, 'media_stream_mic': 2,
                                                    'media_stream_camera': 2, 'protocol_handlers': 2,
                                                    'ppapi_broker': 2, 'automatic_downloads': 2, 'midi_sysex': 2,
                                                    'push_messaging': 2, 'ssl_cert_decisions': 2,
                                                    'metro_switch_to_desktop': 2, 'protected_media_identifier': 2,
                                                    'app_banner': 2, 'site_engagement': 2, 'durable_storage': 2}
# options.add_experimental_option('prefs',prefs )
options.add_argument("start-maximized")
options.add_argument("disable-infobars")
options.add_argument("--disable-extensions")

drv       = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=options)
data_list = [] 
drv.get('https://www.youtube.com/')
# Out:
# /var/folders/tp/dglqnwk96sbbcnl6wq3tl3k00000gn/T/ipykernel_58269/3226614437.py:18: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   drv       = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=options)
# /var/folders/tp/dglqnwk96sbbcnl6wq3tl3k00000gn/T/ipykernel_58269/3226614437.py:18: DeprecationWarning: use options instead of chrome_options
#   drv       = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=options)

# %%
for idx, row in tqdm(data[0:].iterrows(), total = data[0:].shape[0], desc="돌리는중"):

    cd_idx = row['cd_idx']
    search_keyword = row['bd_name']
    print(search_keyword)
    drv.get('https://www.youtube.com/results?search_query=' + str(search_keyword))
    
    
    bd_youtube_search_ko = search_keyword
    no_of_pagedowns = 5
    elem = drv.find_element(By.TAG_NAME, "body")

    while no_of_pagedowns:
        elem.send_keys(Keys.PAGE_DOWN)
        time.sleep(1.2)
        no_of_pagedowns -= 1
    time.sleep(5)  # sleep을 통해 Robot Error 해결.
    soup=BeautifulSoup(drv.page_source, "html")

    Alll=soup.findAll("ytd-video-renderer", {"class":"style-scope ytd-item-section-renderer"})
    if len(Alll) == 0 :
        data_list.append({"cd_idx": cd_idx})
    '#metadata-line > span:nth-child(2)' # view
    'inline-metadata-item style-scope ytd-video-meta-block'# view span class
    '#video-title > yt-formatted-string' # title
    num = 0
    for i in Alll :
        try :
            title =i.find("a",{"id":"video-title"})['title']
        except :
            title = None
        try:
            link = 'https://www.youtube.com' + i.find("a",{"id":"video-title"})['href']
        except:
            link = None
        try:
#             text = i.find("yt-formatted-string",{"id" : "description-text"}).text
            text = i.find("yt-formatted-string",{"class" : "metadata-snippet-text style-scope ytd-video-renderer"}).text            
        except:
            text = None
        try:
            image=i.find('img',{"id":"img"})["src"]

        except:
            print(f"image크롤링오류: {cd_idx}:{image}")
            image = None
        
        try:
            name = i.find('yt-formatted-string',{"class":"style-scope ytd-channel-name complex-string"}).text
        except:
            name = None
            print('name: error')
            
        try :
            duration=i.find('span',{"class":"style-scope ytd-thumbnail-overlay-time-status-renderer"}).text.strip()
        except :
            duration = None
            print('duration: error')
        try :
            viewCount_raw = i.findAll('span',{"class":"inline-metadata-item style-scope ytd-video-meta-block"})[0].text
        except :
            viewCount_raw = None
            print('viewCount_raw: error')
        try :
            regdate_ment = i.findAll('span',{"class":"inline-metadata-item style-scope ytd-video-meta-block"})[1].text
        except :
            regdate_ment = None
            print('regdate_ment: error')
        dataii = {"cd_idx": cd_idx, "bd_youtube_search_ko":search_keyword, "link": link, "title": title,
        "text": text, "image": image, "name": name,
        "duration": duration, "regdate_ment": regdate_ment, "viewCount_raw": viewCount_raw}
        data_list.append(dataii)
        num += 1
        if (num == 10):
            break
            
#제출날짜 및 세트 번호 수정
drv.close()

# %%
data_list
# Out:
# [{'cd_idx': 3193035,
#   'bd_youtube_search_ko': "Take a walk in Harry Potter's magician street, Diagon Alley",
#   'link': 'https://www.youtube.com/watch?v=PjgJZCKaVdI',
#   'title': "Harry Potter and the Sorcerer's Stone (2001) - Diagon Alley Scene",
#   'text': "FILM DESCRIPTION: Harry Potter and the Sorcerer's Stone is a 2001 fantasy film directed by Chris Columbus and distributed by\xa0...",
#   'image': 'https://yt3.ggpht.com/LNf91hjJUCURqg2pNOKEot-QAZ4GQpcCKDLFJfmnJTK159SRgZOZ52jwgmEw_1oQufkftz2W=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Harry Potter Things',
#   'duration': '3:39',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 4.3만회'},
#  {'cd_idx': 3193035,
#   'bd_youtube_search_ko': "Take a walk in Harry Potter's magician street, Diagon Alley",
#   'link': 'https://www.youtube.com/watch?v=1LUNshGrLrk',
#   'title': 'Diagon Alley (Relaxing Walk) Universal Studios Florida | Harry Potter World Full Walking Tour 2020',
#   'text': 'Welcome back to Universal Studios in Orlando, Florida. We are continuing to upload footage from our last trip to Orlando. This will\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu-Qg7t6zytsMh9iDmwaq3VIS4vmXNNSkoNliiQlIg=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Theme Park Shark',
#   'duration': '9:08',
#   'regdate_ment': '2년 전',
#   'viewCount_raw': '조회수 9.1만회'},
#  {'cd_idx': 3193035,
#   'bd_youtube_search_ko': "Take a walk in Harry Potter's magician street, Diagon Alley",
#   'link': 'https://www.youtube.com/shorts/UbkLZ-9GZTs',
#   'title': 'Harry Potter Shop in Edinburgh, Victoria Street, The Real-Life Diagon Alley',
#   'text': 'According to Google maps Victoria Street is the real-life Diagon Alley.',
#   'image': 'https://yt3.ggpht.com/wh4dP5GPIN84g0ncbf6K3bI1jDEyMDo2nIlXN1xGXQgimDoqFXc36UC6YUd82qXcNAwhnARe6w=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Rhona The Unicorn',
#   'duration': 'SHORTS',
#   'regdate_ment': '2주 전',
#   'viewCount_raw': '조회수 1.2천회'},
#  {'cd_idx': 3193035,
#   'bd_youtube_search_ko': "Take a walk in Harry Potter's magician street, Diagon Alley",
#   'link': 'https://www.youtube.com/watch?v=hBZAv-a7crQ',
#   'title': 'Harry Potter London Magic Walking Tour and Film Locations',
#   'text': "Harry Potter London Magic Walking Tour and Film Locations London's favourite guide takes you to all the main Harry Potter film\xa0...",
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu--dQUjg1hNaCvpqH8LQYaQnMw0VJw3Yh92fDxtsA=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Joolz Guides - London History Walks - Travel Films',
#   'duration': '17:25',
#   'regdate_ment': '5년 전',
#   'viewCount_raw': '조회수 97만회'},
#  {'cd_idx': 3193035,
#   'bd_youtube_search_ko': "Take a walk in Harry Potter's magician street, Diagon Alley",
#   'link': 'https://www.youtube.com/watch?v=vMooEWFeerM',
#   'title': "Argh so bright, mah eyes! Weasley's Wizard Wheezes (yep, I totally can't say that correctly) build",
#   'text': "Do orange and purple go together? I'm not exactly convinced, but they certainly make Weasley's Wizard Wheezes stand out from\xa0...",
#   'image': 'https://yt3.ggpht.com/-ERITRszY8GZcyVpv4f_0fx1lArzdlE6wVxfzDeNmXp8jK6XOA5y6tNW2-a0NJW-QJskddXo=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'ellieV ',
#   'duration': '30:15',
#   'regdate_ment': '2년 전',
#   'viewCount_raw': '조회수 88만회'},
#  {'cd_idx': 3193035,
#   'bd_youtube_search_ko': "Take a walk in Harry Potter's magician street, Diagon Alley",
#   'link': 'https://www.youtube.com/watch?v=MZkJtcu-a6I',
#   'title': 'Behind the Bricks: A Tour of Diagon Alley™ with Tom Felton and Matthew Lewis Replay',
#   'text': 'Watch the replay of Tom Felton (who played Draco Malfoy in the films), Matthew Lewis (Neville Longbottom) and Alan Gilmore,\xa0...',
#   'image': 'https://yt3.ggpht.com/AZ9u5at8r2Z-O2O25yYMP_1y9_WNnG5aoLfqJBnCchtKkUHR06hDEpFMout9nFgabI7BPNoJBA=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Universal Orlando Resort',
#   'duration': '12:17',
#   'regdate_ment': '8년 전',
#   'viewCount_raw': '조회수 414만회'},
#  {'cd_idx': 3193035,
#   'bd_youtube_search_ko': "Take a walk in Harry Potter's magician street, Diagon Alley",
#   'link': 'https://www.youtube.com/shorts/Fak6xdM5g5g',
#   'title': 'walking in the streets of  Diagon Alley. #harrypotter #magic #wizard #universalstudios',
#   'text': None,
#   'image': 'https://yt3.ggpht.com/rKme8kVQMVXvLhKsYCN_9ilaUtEUvw2egTdYFPK_DQseMgdp-uU2UWkioO6P_fUx_1w_AR56NQ=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'michal the traveller',
#   'duration': 'SHORTS',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 6회'},
#  {'cd_idx': 3193035,
#   'bd_youtube_search_ko': "Take a walk in Harry Potter's magician street, Diagon Alley",
#   'link': 'https://www.youtube.com/watch?v=OFBDQSNsOc0',
#   'title': "Welcome to Diagon Alley - 'Yer A Wizard' (Part 1/4) - Harry Potter Inspired Sleep Story Meditation",
#   'text': "Welcome to Part One of 'Yer A Wizard', a Harry Potter Sleep Saga where you are the main character. This is the beginning of your\xa0...",
#   'image': 'https://yt3.ggpht.com/FLZNaRt7OUR-bt-jgdmThMK0mc8T32ONRgBUGWd7FL8fVgA7pEDbXC8PaYNvXa5Cr5tqp4SldHA=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Sleepy Cat Meditations',
#   'duration': '2:14:58',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 60만회'},
#  {'cd_idx': 3193035,
#   'bd_youtube_search_ko': "Take a walk in Harry Potter's magician street, Diagon Alley",
#   'link': 'https://www.youtube.com/watch?v=N8FSuOjoy8w',
#   'title': 'Harry Potter and the Escape from Gringotts (Full Ride Experience + Queue POV) Universal Studios',
#   'text': 'Welcome to our official ride pov and full experience for Harry Potter and the Escape from Gringotts located in Diagon Alley at\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu-Qg7t6zytsMh9iDmwaq3VIS4vmXNNSkoNliiQlIg=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Theme Park Shark',
#   'duration': '9:46',
#   'regdate_ment': '2년 전',
#   'viewCount_raw': '조회수 266만회'},
#  {'cd_idx': 3193035,
#   'bd_youtube_search_ko': "Take a walk in Harry Potter's magician street, Diagon Alley",
#   'link': 'https://www.youtube.com/watch?v=oub2os2msPM',
#   'title': 'Lego Harry Potter Years 1-4: Diagon Alley and more FREE ROAM (All collectibles) - HTG',
#   'text': '(HTG) Brian walks you through The Diagon Alley, The Leaky Cauldron and Knockturn Alley FREE ROAM for Lego Harry Potter\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu8Voy7uPjf8mRQo8O-gzcCniT30XMQqACrBXupC=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'HappyThumbsGaming',
#   'duration': '9:17',
#   'regdate_ment': '7년 전',
#   'viewCount_raw': '조회수 22만회'},
#  {'cd_idx': 3193036,
#   'bd_youtube_search_ko': 'Explore the American Museum of Natural History, Humans, Life, and the Universe',
#   'link': 'https://www.youtube.com/watch?v=4KRZQQ_eICo',
#   'title': 'SciCafe: Life the Universe and Everything with Neil deGrasse Tyson',
#   'text': 'American Museum of Natural History\'s Director of the Hayden Planetarium, Neil deGrasse Tyson, hosted "Life the Universe and\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu9--JJiWoJaoLrlTMVbtBS-P1WKeibKSH2kqODvnQ=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'American Museum of Natural History',
#   'duration': '1:28:27',
#   'regdate_ment': '12년 전',
#   'viewCount_raw': '조회수 293만회'},
#  {'cd_idx': 3193036,
#   'bd_youtube_search_ko': 'Explore the American Museum of Natural History, Humans, Life, and the Universe',
#   'link': 'https://www.youtube.com/watch?v=17jymDn0W6U',
#   'title': 'The Known Universe by AMNH',
#   'text': 'Data: Digital Universe, American Museum of Natural History http://www.haydenplanetarium.org/universe/ Visualization Software:\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu9--JJiWoJaoLrlTMVbtBS-P1WKeibKSH2kqODvnQ=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'American Museum of Natural History',
#   'duration': '6:31',
#   'regdate_ment': '12년 전',
#   'viewCount_raw': '조회수 1685만회'},
#  {'cd_idx': 3193036,
#   'bd_youtube_search_ko': 'Explore the American Museum of Natural History, Humans, Life, and the Universe',
#   'link': 'https://www.youtube.com/watch?v=Rr5IvB6QpB4',
#   'title': 'BUENA VISTA MUSEUM OF NATURAL HISTORY AND SCIENCE: SHARKS, DINOSAURS, ANIMALS, AND MORE',
#   'text': 'Goose and Logan explore the Buena Vista Museum of Natural History and Science and discover exhibits from dinosaurs\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu8ND6pluWvWoNW-zpLzalp8l1Z7kwuhQX0Jw8BL=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Travel By N8ture',
#   'duration': '30:32',
#   'regdate_ment': '3일 전',
#   'viewCount_raw': '조회수 25회'},
#  {'cd_idx': 3193036,
#   'bd_youtube_search_ko': 'Explore the American Museum of Natural History, Humans, Life, and the Universe',
#   'link': 'https://www.youtube.com/watch?v=AbLNPMZGN9M',
#   'title': 'American Museum of Natural History - Walkthrough Part 1 / 1st Floor',
#   'text': 'In this video, part 1 of 4, I walk through the 1st floor of the American Museum of Natural History in NYC. This museum has such a\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu_kz46Fr2TCTSSkgwuDC6x748FwNMiQe8vLZtYh=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'ML Walks',
#   'duration': '36:29',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 2.7만회'},
#  {'cd_idx': 3193036,
#   'bd_youtube_search_ko': 'Explore the American Museum of Natural History, Humans, Life, and the Universe',
#   'link': 'https://www.youtube.com/watch?v=Xzo6z0d2yA8',
#   'title': 'Natural History Museum of Los Angeles County - Dinosaur Skeletons & Animal Diorama Exhibits',
#   'text': 'We took a trip to the Natural History Museum of Los Angeles. In the center of the museum is the main attraction, the skeletons of a\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu9ZUUijArGRKMicN32880Owx9pQ2h91WL7sNZBhuQ=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'VentureFull',
#   'duration': '3:25',
#   'regdate_ment': '6일 전',
#   'viewCount_raw': '조회수 79회'},
#  {'cd_idx': 3193036,
#   'bd_youtube_search_ko': 'Explore the American Museum of Natural History, Humans, Life, and the Universe',
#   'link': 'https://www.youtube.com/watch?v=wxZLWezpYss',
#   'title': 'Are we alone in the universe?',
#   'text': 'Will we ever find intelligent life in the universe? Astrophysicist Jackie Faherty explains two ways scientists approach answering\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu9--JJiWoJaoLrlTMVbtBS-P1WKeibKSH2kqODvnQ=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'American Museum of Natural History',
#   'duration': '2:51',
#   'regdate_ment': '3년 전',
#   'viewCount_raw': '조회수 4만회'},
#  {'cd_idx': 3193036,
#   'bd_youtube_search_ko': 'Explore the American Museum of Natural History, Humans, Life, and the Universe',
#   'link': 'https://www.youtube.com/watch?v=DZv8VyIQ7YU',
#   'title': 'Seven Million Years of Human Evolution',
#   'text': 'Scientists use fossils to reconstruct the evolutionary history of hominins—the group that includes modern humans, our immediate\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu9--JJiWoJaoLrlTMVbtBS-P1WKeibKSH2kqODvnQ=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'American Museum of Natural History',
#   'duration': '6:23',
#   'regdate_ment': '4년 전',
#   'viewCount_raw': '조회수 200만회'},
#  {'cd_idx': 3193036,
#   'bd_youtube_search_ko': 'Explore the American Museum of Natural History, Humans, Life, and the Universe',
#   'link': 'https://www.youtube.com/watch?v=pPhpzqz84iQ',
#   'title': 'T. rex: The King of Time (and Pop Culture)',
#   'text': 'The Tyrannosaurus rex on display at the American Museum of Natural History has been the tyrant lizard king of the public\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu9--JJiWoJaoLrlTMVbtBS-P1WKeibKSH2kqODvnQ=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'American Museum of Natural History',
#   'duration': '11:01',
#   'regdate_ment': '3년 전',
#   'viewCount_raw': '조회수 6.7만회'},
#  {'cd_idx': 3193036,
#   'bd_youtube_search_ko': 'Explore the American Museum of Natural History, Humans, Life, and the Universe',
#   'link': 'https://www.youtube.com/watch?v=N-7D93_RBnw',
#   'title': 'The American Museum of Natural History',
#   'text': 'The American Museum of Natural History (abbreviated as AMNH), located on the Upper West Side of Manhattan, New York City,\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu888Imjojhp7H6hRnvegd8tqmB_a7td3eNccdunCQ=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Idiotic Seeker',
#   'duration': '10:36',
#   'regdate_ment': '4년 전',
#   'viewCount_raw': '조회수 4.7만회'},
#  {'cd_idx': 3193036,
#   'bd_youtube_search_ko': 'Explore the American Museum of Natural History, Humans, Life, and the Universe',
#   'link': 'https://www.youtube.com/watch?v=PUwmA3Q0_OE',
#   'title': 'Human Population Through Time',
#   'text': 'It took 200000 years for our human population to reach 1 billion—and only 200 years to reach 7 billion. But growth has begun\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu9--JJiWoJaoLrlTMVbtBS-P1WKeibKSH2kqODvnQ=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'American Museum of Natural History',
#   'duration': '6:25',
#   'regdate_ment': '6년 전',
#   'viewCount_raw': '조회수 1788만회'},
#  {'cd_idx': 3193037,
#   'bd_youtube_search_ko': 'Take a walk to Kualoa Ranch, the primitive environment',
#   'link': 'https://www.youtube.com/shorts/GjO4u91jb0I',
#   'title': 'WALK TO SECRET ISLAND Kualoa',
#   'text': 'shorts #hawaii #lifestyle #travel Follow me on Instagram: https://www.instagram.com/hiderrick_/ HiDerrick Merchandise:\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu-L66J5hD8wB5Q2acMQEVoKL6PLF6pdsNKao5Ti=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'HIderrick',
#   'duration': 'SHORTS',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 386회'},
#  {'cd_idx': 3193037,
#   'bd_youtube_search_ko': 'Take a walk to Kualoa Ranch, the primitive environment',
#   'link': 'https://www.youtube.com/watch?v=7M0k4prAW_Y',
#   'title': 'Hawaii Things to Do on Windward Oahu | Lanikai Beach to Kualoa Ranch',
#   'text': 'We love to get out of Waikiki to explore #Oahu, Hawaii. Windward Oahu is home to our favorite beach, #Lanikai Beach, but also so\xa0...',
#   'image': 'https://yt3.ggpht.com/9CdTV4tg_VIvq57K3mfL40XQ9M8wsEJ34Q46XXcnOPD8XqkvdMVS3orWGYpPwyfGPMuCTnUmIw=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'The Hawaii Vacation Guide',
#   'duration': '10:23',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 2.6만회'},
#  {'cd_idx': 3193037,
#   'bd_youtube_search_ko': 'Take a walk to Kualoa Ranch, the primitive environment',
#   'link': 'https://www.youtube.com/watch?v=FDdPrNPLgM8',
#   'title': 'Exploring Kualoa Ranch in Kaneohe, Hawaii USA Walking Tour',
#   'text': 'Exploration To Go takes you on a walking tour through Kualoa Ranch in Kaneohe, Hawaii USA in stunning 4K UHD at 60 fps with\xa0...',
#   'image': 'https://yt3.ggpht.com/MWgc4eTAKUc0B1nHWBBnCi07Jl8auGuG0iAnj9S-T63-TyxO5OPK3mvbBdislKY3BwOJrFLibgg=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Exploration To Go',
#   'duration': '49:08',
#   'regdate_ment': '3개월 전',
#   'viewCount_raw': '조회수 261회'},
#  {'cd_idx': 3193037,
#   'bd_youtube_search_ko': 'Take a walk to Kualoa Ranch, the primitive environment',
#   'link': 'https://www.youtube.com/watch?v=jQ1sijT8Afs',
#   'title': 'Kualoa Ranch Private Nature Reserve | Movie Site Tour 🌴 Oahu, Hawaii 4K Tour',
#   'text': "Kualoa Ranch Movie Site Tour Oahu, Hawaii 4K Tour 700+ Various Videos are on the 'Hawaii John' channel FREE PARKING\xa0...",
#   'image': 'https://yt3.ggpht.com/eXlveIJ5rycD803Lg7buLdckPB8Peb_rIxUCw-RQIu8lhL4uLezihl_EzLi3fxyBGIdLOHiyXA=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Hawaii John',
#   'duration': '1:26:28',
#   'regdate_ment': '2년 전',
#   'viewCount_raw': '조회수 1.4만회'},
#  {'cd_idx': 3193037,
#   'bd_youtube_search_ko': 'Take a walk to Kualoa Ranch, the primitive environment',
#   'link': 'https://www.youtube.com/watch?v=OzmZn39p4iQ',
#   'title': "KUALOA RANCH OAHU HAWAII, WHERE MOVIES LIKE JURASSIC PARK ARE MADE. LET'S LOOK BEHIND THE SCENES.",
#   'text': "Kualoa ranch Oahu Hawaii, where movies like Jurassic Park are made. Let's look behind the scenes. Dan & Sally explore the\xa0...",
#   'image': 'https://yt3.ggpht.com/VvlbG97oJ4ySMSLJK0XJBNXAGi-KKGNTuxXU-6NHZedkuv32b75nDHEGuakba9gu4q-ltKptcQ=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Daniel Dawson',
#   'duration': '7:32',
#   'regdate_ment': '9개월 전',
#   'viewCount_raw': '조회수 383회'},
#  {'cd_idx': 3193037,
#   'bd_youtube_search_ko': 'Take a walk to Kualoa Ranch, the primitive environment',
#   'link': 'https://www.youtube.com/shorts/7Qmx5oPjylI',
#   'title': '#shorts📍Pt 1 Secret Island Beach at Kualoa Ranch 🦕Amazing Views ! .#travelvlog #family #beachlife',
#   'text': None,
#   'image': 'https://yt3.ggpht.com/iNtv7P4LJT-QeeiCOsfhwYNMPKvkoje1L-ewVCkSdTsLftUL1NPH30Syalje-not4sqGeWKLY84=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Infinite Soul Vibes',
#   'duration': 'SHORTS',
#   'regdate_ment': '4주 전',
#   'viewCount_raw': '조회수 926회'},
#  {'cd_idx': 3193037,
#   'bd_youtube_search_ko': 'Take a walk to Kualoa Ranch, the primitive environment',
#   'link': 'https://www.youtube.com/watch?v=u-c1LCx3XRI',
#   'title': 'Jurassic Park Tour at Kualoa Ranch 🦖',
#   'text': 'We went to Kualoa Ranch in Oahu, Hawaii to take the brand new Jurassic Adventure Tour! This two hour tour took us deep into\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu-DLdQNvZAAQsgRw5T5eRyUy815zvp8-jaDvS_UAw=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Ordinary Adventures',
#   'duration': '28:16',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 25만회'},
#  {'cd_idx': 3193037,
#   'bd_youtube_search_ko': 'Take a walk to Kualoa Ranch, the primitive environment',
#   'link': 'https://www.youtube.com/watch?v=nAW-GnVhRlA',
#   'title': 'Kualoa Ranch | Movie Site and Jurassic Tour | Honolulu, Hawaii | November 26&27, 2022',
#   'text': None,
#   'image': 'https://yt3.ggpht.com/yo3rnuVRawgxcqFKvVpkkZj0FldAJhkHu9XBUQQ4Zg81GICOnjFk48O-SsUjYWwqPO1EYR3L=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Learn and Play with Dylan',
#   'duration': '9:47',
#   'regdate_ment': '9시간 전',
#   'viewCount_raw': '조회수 26회'},
#  {'cd_idx': 3193037,
#   'bd_youtube_search_ko': 'Take a walk to Kualoa Ranch, the primitive environment',
#   'link': 'https://www.youtube.com/watch?v=-JKUDxtiTwg',
#   'title': "Kualoa Ranch Secret Island / Review & Tips / O'ahu, Hawaii",
#   'text': 'Things you may need on the Island As an Amazon Associate I earn from qualifying purchases 1. Long sleeve UV Sun Protection\xa0...',
#   'image': 'https://yt3.ggpht.com/HI6ADSr61agEBFaQ2yqwoJjR7qIbPRpVsn5iXwFtSij5jtKf8Zc5xD3R9dfWSkYtPmmbV_NFdg=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'NiambiKnows',
#   'duration': '4:17',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 4천회'},
#  {'cd_idx': 3193037,
#   'bd_youtube_search_ko': 'Take a walk to Kualoa Ranch, the primitive environment',
#   'link': 'https://www.youtube.com/watch?v=zd4Pz61PdzA',
#   'title': 'Jurassic Adventure Tour at Kualoa Ranch! | Oahu, Hawaii',
#   'text': 'Welcome to Jurassic Park! We are at Kualoa Ranch for their 2.5 hour Jurassic Adventure Tour! This tour offers you the chance to\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu9Wgb98CFfRH1XbY3c1uemVn3yaQEQ3D-UUCxU2=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'MattAndAlex',
#   'duration': '21:28',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 8.6천회'},
#  {'cd_idx': 3193038,
#   'bd_youtube_search_ko': 'Relax by yourself in luxury and antique Plaza Hotel',
#   'link': 'https://www.youtube.com/watch?v=jNzq08ZR--g',
#   'title': 'Relax In A Luxury  Apartment | Smooth Piano Jazz Music - Instrumental Background for Relax, Study',
#   'text': 'Relax In A Luxury Apartment | Smooth Piano Jazz Music - Instrumental Background for Relax, Study. This is the perfect moment\xa0...',
#   'image': 'https://yt3.ggpht.com/y-EOwC6632dWqU98ValSDmoWKzZ0DDVAdCimgtTuJRCkz6YTsoeFOiyYotWX71Kqo3tt7lYr4w=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Cozy Bedroom',
#   'duration': '11:55:00',
#   'regdate_ment': '스트리밍 시간: 1개월 전',
#   'viewCount_raw': '조회수 6.4만회'},
#  {'cd_idx': 3193038,
#   'bd_youtube_search_ko': 'Relax by yourself in luxury and antique Plaza Hotel',
#   'link': 'https://www.youtube.com/watch?v=th-7DRaELLA',
#   'title': 'Relax Music - Luxury Hotel JAZZ - Exquisite Mountain Hotel Jazz Music To Relax, Work & Study',
#   'text': 'Jazz and Bossa Nova Music is perfect to assist your relaxation, reading, studying, work, sleeping, focusing, stress relief, romantic\xa0...',
#   'image': 'https://yt3.ggpht.com/lCtNZz3ygAJxPHt5vxigBisHY3Oe0rHFMdnFiZIfJveZKEXY4OzapSDw4xhVrNuNVzDGnMZF=s88-c-k-c0x00ffffff-no-rj',
#   'name': 'Relax Music',
#   'duration': '6:48:31',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 23만회'},
#  {'cd_idx': 3193038,
#   'bd_youtube_search_ko': 'Relax by yourself in luxury and antique Plaza Hotel',
#   'link': 'https://www.youtube.com/watch?v=i7Wp1UNaffU',
#   'title': '4K Cozy Bedroom in New York City with Jazz Music for Relax and Study',
#   'text': '4K Cozy Bedroom in New York City with Jazz Music for Relax and Study. If you are always in search of the perfect music to help\xa0...',
#   'image': 'https://yt3.ggpht.com/zgLe_8SoOv_FkTeAsKJrCZARGFOPcTclauUOFdv_Ulxng3_OssL5HRmSWS9u4QzIroRBlAWZ=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Jazzy Coffee',
#   'duration': '3:36:37',
#   'regdate_ment': '8개월 전',
#   'viewCount_raw': '조회수 146만회'},
#  {'cd_idx': 3193038,
#   'bd_youtube_search_ko': 'Relax by yourself in luxury and antique Plaza Hotel',
#   'link': 'https://www.youtube.com/watch?v=xmn0RjUVt1U',
#   'title': 'Deep Sleep with Blizzard and Fireplace Sounds | Cozy Winter Ambience, Snow Storm and Wind Sound',
#   'text': 'blizzard #snowfall #winterambience Fall into deep sleep with the sounds of a blizzard and a fireplace. This cozy winter\xa0...',
#   'image': 'https://yt3.ggpht.com/REvMcKL5qB9AtHkVJegYTTkaQyb6BN4kpnrbHEcqqWd28IZN1i3WnyuJfj54QxJ49JI_hcI1-hk=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Rainy Guy',
#   'duration': '8:00:01',
#   'regdate_ment': '6개월 전',
#   'viewCount_raw': '조회수 230만회'},
#  {'cd_idx': 3193038,
#   'bd_youtube_search_ko': 'Relax by yourself in luxury and antique Plaza Hotel',
#   'link': 'https://www.youtube.com/watch?v=gZauVyMJtP0',
#   'title': '🇲🇲4K Vintage Luxury Yacht  Hotel Opposite to Yangon’s Slums: Dala｜ဒလမြို့နယ်｜住懷舊豪華遊艇酒店，探仰光德拉貧民窟',
#   'text': 'Vintage Luxury Yacht Hotel is situated just around the corner of Botahtaung Pagoda at Botahtaung Jetty anchored in the Yangon\xa0...',
#   'image': 'https://yt3.ggpht.com/E1jV1Vs4rLA_v_68VVP33PZLBzJ8nWk5uOMAbiHJwSGcJ9NuyjlMrRpmMhFbRfRiuqE6V7YJ4c0=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Meowsaga',
#   'duration': '14:01',
#   'regdate_ment': '1일 전',
#   'viewCount_raw': '조회수 28회'},
#  {'cd_idx': 3193038,
#   'bd_youtube_search_ko': 'Relax by yourself in luxury and antique Plaza Hotel',
#   'link': 'https://www.youtube.com/watch?v=ac--PyDtQBs',
#   'title': 'Relax Music - Luxury Jazz - Luxury Smooth Music - Chill Jazz',
#   'text': 'Jazz and Bossa Nova Music is perfect to assist your relaxation, reading, studying, work, sleeping, focusing, stress relief, romantic\xa0...',
#   'image': 'https://yt3.ggpht.com/lCtNZz3ygAJxPHt5vxigBisHY3Oe0rHFMdnFiZIfJveZKEXY4OzapSDw4xhVrNuNVzDGnMZF=s88-c-k-c0x00ffffff-no-rj',
#   'name': 'Relax Music',
#   'duration': '6:34:51',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 64만회'},
#  {'cd_idx': 3193038,
#   'bd_youtube_search_ko': 'Relax by yourself in luxury and antique Plaza Hotel',
#   'link': 'https://www.youtube.com/watch?v=dOrXXCm6U8M',
#   'title': '(Night Version For Sleeping) NYC Heavy Snowfall In A Cozy Apartment | 4K |  60FPS',
#   'text': 'This is my night, especially made for sleeping version, of my 4 Hour 60fps Heavy snowfall NYC Rooftop Ambience day scene.',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu9kbubw4hpWamI-dU09xQDeii_yj8upvHt26hhL=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Ambient Renders',
#   'duration': '8:00:00',
#   'regdate_ment': '10개월 전',
#   'viewCount_raw': '조회수 18만회'},
#  {'cd_idx': 3193038,
#   'bd_youtube_search_ko': 'Relax by yourself in luxury and antique Plaza Hotel',
#   'link': 'https://www.youtube.com/watch?v=D_aSKfLA-lo',
#   'title': 'A Luxury New York Apartment With An Amazing View - Smooth Jazz Piano Music for Relax and Sleep',
#   'text': 'A Luxury New York Apartment With An Amazing View - Smooth Jazz Piano Music for Relax and Sleep. This is an ambient video of\xa0...',
#   'image': 'https://yt3.ggpht.com/0YchgkcqbC3TktvHKobb4R8mdYyOy50q4lS6U7D7sN4hhzoxWxZuyZvByn9qeaIO80XR7b1t=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Cozy Apartment',
#   'duration': '8:22:03',
#   'regdate_ment': '10개월 전',
#   'viewCount_raw': '조회수 33만회'},
#  {'cd_idx': 3193038,
#   'bd_youtube_search_ko': 'Relax by yourself in luxury and antique Plaza Hotel',
#   'link': 'https://www.youtube.com/watch?v=GcgfjEWe_PM',
#   'title': 'Night Jazz in Luxury Apartments in Malaysia - Instrumental Background for Relax, Study, Work',
#   'text': 'Night Jazz in Luxury Apartments in Malaysia - Instrumental Background for Relax, Study, Work. This cozy apartment in Malaysia\xa0...',
#   'image': 'https://yt3.ggpht.com/y-EOwC6632dWqU98ValSDmoWKzZ0DDVAdCimgtTuJRCkz6YTsoeFOiyYotWX71Kqo3tt7lYr4w=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Cozy Bedroom',
#   'duration': '3:38:18',
#   'regdate_ment': '8개월 전',
#   'viewCount_raw': '조회수 62만회'},
#  {'cd_idx': 3193038,
#   'bd_youtube_search_ko': 'Relax by yourself in luxury and antique Plaza Hotel',
#   'link': 'https://www.youtube.com/watch?v=_d2XfUXn0kY',
#   'title': 'Jacuzzi Lifeguard - SNL',
#   'text': 'A man (Will Ferrell) tries to relax in a jacuzzi but a loud, hyperactive lifeguard (Jim Carrey) ruins it with every tool of the lifeguard\xa0...',
#   'image': 'https://yt3.ggpht.com/E6aCdB-Kgx60Y1ZJ-c_YFwHYa7Eah5Bu33kNVoGogzv3WfTQUjLjCItlF8JwOZMdNVYRPkuiVQ=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Saturday Night Live',
#   'duration': '6:01',
#   'regdate_ment': '9년 전',
#   'viewCount_raw': '조회수 1344만회'},
#  {'cd_idx': 3193039,
#   'bd_youtube_search_ko': 'Read books in a romantic city of literature, Nottinghill',
#   'link': 'https://www.youtube.com/watch?v=zQAXS73hHVM',
#   'title': 'Learn English Through Story~Level 3~Notting Hill~English story for learning English with subtitles',
#   'text': 'Audiobooks in english. Notting Hill by Richard Curtis. Level 3. #learnengishthroughstory #englishstory #englishaudiobook.',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu9XTV0iLsarBQ1-JQN3BuvzHFgy4oLoXRkNotp1xQ=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Colour Pages',
#   'duration': '1:51:02',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 5.8만회'},
#  {'cd_idx': 3193039,
#   'bd_youtube_search_ko': 'Read books in a romantic city of literature, Nottinghill',
#   'link': 'https://www.youtube.com/shorts/dqV0sQNsEOc',
#   'title': 'Top 6 fav. books ever!🔥|#booktok #booktube #bookrecommendations #tiktok #shorts #bookish #reading',
#   'text': None,
#   'image': 'https://yt3.ggpht.com/NjZmBu2xCL5qea8TMZQbxKsUQRuRUZcfLLovKet3hds9GvSuvQAcMTDkXPgUlKfYMa0ZxB-v-kc=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Gianna Lian',
#   'duration': 'SHORTS',
#   'regdate_ment': '3개월 전',
#   'viewCount_raw': '조회수 3.1만회'},
#  {'cd_idx': 3193039,
#   'bd_youtube_search_ko': 'Read books in a romantic city of literature, Nottinghill',
#   'link': 'https://www.youtube.com/shorts/JgycktWbI0E',
#   'title': 'Spicy Book Recommendations! #shorts',
#   'text': 'Hi my beautiful fam♡ OPEN ME♡ ➡️ Spicy Book Recommendations! #shorts What is this video about? - Spicy Booktok books\xa0...',
#   'image': 'https://yt3.ggpht.com/4tDykdrl_hEJv_huTnDqKke8FtOOVakX2pg2TsQn8puak3G8bek7HAEErRAFOVIrSBC4I12W-tI=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'i s a b e l l a ☺',
#   'duration': 'SHORTS',
#   'regdate_ment': '7개월 전',
#   'viewCount_raw': '조회수 18만회'},
#  {'cd_idx': 3193039,
#   'bd_youtube_search_ko': 'Read books in a romantic city of literature, Nottinghill',
#   'link': 'https://www.youtube.com/watch?v=Adfk3qNAErM',
#   'title': 'Reading an old love story in the rain while waiting for your train// a dark academia playlist',
#   'text': 'I hope you all enjoy this playlist!! Stay happy and healthy everyone!! :)) Here is an extended version of the title, since I really like it\xa0...',
#   'image': 'https://yt3.ggpht.com/JABBfspnhSgS-51Q19CFS3Vzh702hQqfWNAGVeV5wMAFCuiJ0YQfVnEL_d7NGZ54doLD0B0vw-k=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Ivoryyy',
#   'duration': '40:01',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 194만회'},
#  {'cd_idx': 3193039,
#   'bd_youtube_search_ko': 'Read books in a romantic city of literature, Nottinghill',
#   'link': 'https://www.youtube.com/shorts/g0_i2jUAT_E',
#   'title': 'Fast paced books to get you out of a reading slump 📖 #books',
#   'text': None,
#   'image': 'https://yt3.ggpht.com/cokFIFw4ihnS0YLl4kp4S59cNGoJIb2adLW8I-Ui1UNsX1ATvMrgtlbp6wvOHmZ47As1l-Y5=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Joe Wilkinson',
#   'duration': 'SHORTS',
#   'regdate_ment': '5개월 전',
#   'viewCount_raw': '조회수 42만회'},
#  {'cd_idx': 3193039,
#   'bd_youtube_search_ko': 'Read books in a romantic city of literature, Nottinghill',
#   'link': 'https://www.youtube.com/watch?v=bZMXZ33Tp30',
#   'title': '6 Books You Should Read in the Cities Where They Take Place',
#   'text': "While there's something appealing about flipping through a book poolside, it's a truly transcendent experience to indulge in one in\xa0...",
#   'image': 'https://yt3.ggpht.com/159hizyDJbqO1jwEaD80nuNWlnnJlaGkHSCw0E0XzCgKk5HduwvNVPehdpzP--2meq6BdNrktps=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'POPSUGAR',
#   'duration': '2:19',
#   'regdate_ment': '7년 전',
#   'viewCount_raw': '조회수 1.6만회'},
#  {'cd_idx': 3193039,
#   'bd_youtube_search_ko': 'Read books in a romantic city of literature, Nottinghill',
#   'link': 'https://www.youtube.com/watch?v=KwXyVh1zIhM',
#   'title': 'a playlist for night readers (dark academia)',
#   'text': 'youtube put ads for copyright claim, so click → 1:05:56 ← to SKIP ALL THE ADS, then replay SPOTIFY PLAYLIST\xa0...',
#   'image': 'https://yt3.ggpht.com/83JvYUBJgIl8IsAEpql4MDfpSxv6mk5uPrdGBlhM5Cld_kbX5ihUyz_87Dp2ls6WyfwJdk2E8Q=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'nobody',
#   'duration': '1:05:56',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 321만회'},
#  {'cd_idx': 3193039,
#   'bd_youtube_search_ko': 'Read books in a romantic city of literature, Nottinghill',
#   'link': 'https://www.youtube.com/watch?v=5aINUtydgXI',
#   'title': 'Bug City by Dahlov Ipcar | Read Aloud for Kids! | The Joyful Bookshelf',
#   'text': 'Book: Bug City by Dahlov Ipcar Hello and Welcome to The Joyful Bookshelf where books are FUN! This channel is dedicated\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu_PnPxlcCMylQQVsaJJfyddVjAsct0sx1KiyrNM=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'The Joyful Bookshelf',
#   'duration': '4:33',
#   'regdate_ment': '2년 전',
#   'viewCount_raw': '조회수 7.9천회'},
#  {'cd_idx': 3193039,
#   'bd_youtube_search_ko': 'Read books in a romantic city of literature, Nottinghill',
#   'link': 'https://www.youtube.com/watch?v=Kz2AN3Ot3I0',
#   'title': "i read 36 NEW romances, let me tell you what's good (and really really bad)",
#   'text': "BUS INQ: chandler.ainsley@thestation.io FAQS ◈ Where do you put your dust jackets?! - they're in a storage container in my\xa0...",
#   'image': 'https://yt3.ggpht.com/PI0aaRUYu338tL196UpAzBx5r6roS2ZPnw2vQBhQNYEbYu2bDox0aF2xXYDDGMiluVQ2LMoafQ=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'chandler ainsley',
#   'duration': '44:09',
#   'regdate_ment': '1개월 전',
#   'viewCount_raw': '조회수 8.6만회'},
#  {'cd_idx': 3193039,
#   'bd_youtube_search_ko': 'Read books in a romantic city of literature, Nottinghill',
#   'link': 'https://www.youtube.com/watch?v=Ia19O6moOrY',
#   'title': 'the smell of old books, rain and hot tea (in a playlist)',
#   'text': 'my three favorite things + grandpa sweaters 9.8.21 spotify playlist\xa0...',
#   'image': 'https://yt3.ggpht.com/SRi_2jpJfqZUV43QzeX9JCyOGEQP_L6e0S92AAjz5Z9cUv_Zg4wW_iBwiYMsyaGKUGTU17Yc=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'oliviaalee',
#   'duration': '1:01:56',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 52만회'},
#  {'cd_idx': 3193041,
#   'bd_youtube_search_ko': 'Look around Christ Church campus at Oxford University',
#   'link': 'https://www.youtube.com/watch?v=0jTbl-S0Q4s',
#   'title': 'Christ Church: A Tour',
#   'text': 'Student Rafi gives a tour of Christ Church, one of the largest colleges in Oxford with a vibrant academic community in a diverse\xa0...',
#   'image': 'https://yt3.ggpht.com/MhF9YjnU__0isKph7zPOgNUlTQcCGkM1MVONaCiGzGNKiikqqqAzvLG2QlySASCCDWS2IHFS=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Graduate Study at Oxford',
#   'duration': '7:16',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 3.3만회'},
#  {'cd_idx': 3193041,
#   'bd_youtube_search_ko': 'Look around Christ Church campus at Oxford University',
#   'link': 'https://www.youtube.com/watch?v=_nZHYggiRJ4',
#   'title': 'Walking around Oxford: Inside the Christ Church (College) a.k.a. Hogwarts',
#   'text': 'Using: Insta360 Go 2 (affiliate link) https://www.insta360.com/sal/go_2?insrc=INR72J1 I use Epidemic Sound, sign up for a 30-day\xa0...',
#   'image': 'https://yt3.ggpht.com/eZCXYduPsyie06bdOAEDktIJLQSiOhW-mCZPWbZCaM-FhLLOFBOd1USnouOkclJ74oqIKVgJmA=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Surfing Through Life as a Postdoc',
#   'duration': '14:57',
#   'regdate_ment': '10개월 전',
#   'viewCount_raw': '조회수 4.2천회'},
#  {'cd_idx': 3193041,
#   'bd_youtube_search_ko': 'Look around Christ Church campus at Oxford University',
#   'link': 'https://www.youtube.com/watch?v=27Quo0eoX9A',
#   'title': 'Inside Christ Church College & Cathedral, Oxford!',
#   'text': 'Having a look around the stunning Christ Church College in Oxford, the staircase leading to the great hall is famous for being\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu8s5OhNgYL2WJ7Tdt6rc-MVGfv13hx-9uW2q6x26w=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Vermilion Studios',
#   'duration': '8:32',
#   'regdate_ment': '3년 전',
#   'viewCount_raw': '조회수 4.7천회'},
#  {'cd_idx': 3193041,
#   'bd_youtube_search_ko': 'Look around Christ Church campus at Oxford University',
#   'link': 'https://www.youtube.com/watch?v=CJg5_didUdM',
#   'title': 'Christ Church, Oxford: Accommodation and Catering',
#   'text': None,
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu90ozkSRk9ietOMaEj1PgG79T7p29Y3C0bGpvNd=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Christ Church',
#   'duration': '5:52',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 6.2천회'},
#  {'cd_idx': 3193041,
#   'bd_youtube_search_ko': 'Look around Christ Church campus at Oxford University',
#   'link': 'https://www.youtube.com/watch?v=N-lQKWF632s',
#   'title': 'Christ Church College, University of Oxford Tour & History (a sort of mini documentary)',
#   'text': 'This video was filmed on September 27th 2019 on my graduation day. I have put the transcript for the video in the pinned\xa0...',
#   'image': 'https://yt3.ggpht.com/vkLyME9ghHWjHG5FabwXZfd69BvhktxsnD-K-iEOKTBdq4JDNzG4EQeorNWiVv5Dgdn982J11g=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Rosie Crawford',
#   'duration': '7:59',
#   'regdate_ment': '2년 전',
#   'viewCount_raw': '조회수 1.3만회'},
#  {'cd_idx': 3193041,
#   'bd_youtube_search_ko': 'Look around Christ Church campus at Oxford University',
#   'link': 'https://www.youtube.com/watch?v=2oxZUpJcK70',
#   'title': 'Oxford University, Christ Church college',
#   'text': 'Christ Church is a constituent college of the Oxford University. Christ Church college has produced thirteen British prime ministers,\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu-IN45uhxWqCwZd1Ul26U1lyXs7Qz8cw44CbO_AQw=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Irina Palok',
#   'duration': '3:47',
#   'regdate_ment': '5년 전',
#   'viewCount_raw': '조회수 5만회'},
#  {'cd_idx': 3193041,
#   'bd_youtube_search_ko': 'Look around Christ Church campus at Oxford University',
#   'link': 'https://www.youtube.com/watch?v=uR9lHn2sPKc',
#   'title': "Touring Oxford University's Christ Church College",
#   'text': 'During our monumental trip to England, Tarah and I spent a day in the historic city of Oxford. Though short on time, we did make\xa0...',
#   'image': 'https://yt3.ggpht.com/7Py1qNlmx8rsynuLYHAu4LciqIYClCckuGNANgetiu9hU5S05-qyGGylduRbWKeosELg29KJ9ek=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Lost in the Pond',
#   'duration': '11:07',
#   'regdate_ment': '3년 전',
#   'viewCount_raw': '조회수 1.1만회'},
#  {'cd_idx': 3193041,
#   'bd_youtube_search_ko': 'Look around Christ Church campus at Oxford University',
#   'link': 'https://www.youtube.com/watch?v=cqlAY-ledus',
#   'title': 'Architecture of Christ Church: Judith Curthoys',
#   'text': "Archivist of Christ Church Judith Curthoys discusses Oxford's grandest college, and its unusual foundation -- first by a cardinal,\xa0...",
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu9VRGbuCn5-ToYFlZqHZ1ZHo_VqxY7OVaOqeI1W0g=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'University of Oxford',
#   'duration': '4:21',
#   'regdate_ment': '8년 전',
#   'viewCount_raw': '조회수 1.3만회'},
#  {'cd_idx': 3193041,
#   'bd_youtube_search_ko': 'Look around Christ Church campus at Oxford University',
#   'link': 'https://www.youtube.com/watch?v=Lhx_oqN6CU0',
#   'title': 'Christ Church College | University of Oxford',
#   'text': 'Christ Church College was where several scenes in Harry Potter were filmed. The Christ Church Great Hall also provided the\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu_4f3vfjUenVjskY9VClQwQtT27TdzkrG53_Dtp=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'HWOLO',
#   'duration': '6:00',
#   'regdate_ment': '1년 전',
#   'viewCount_raw': '조회수 1.1천회'},
#  {'cd_idx': 3193041,
#   'bd_youtube_search_ko': 'Look around Christ Church campus at Oxford University',
#   'link': 'https://www.youtube.com/watch?v=JQ6E4cslWiw',
#   'title': 'CHRIST CHURCH OXFORD TOUR',
#   'text': "Take a brief peek into one of Oxford' University's most celebrated colleges, Christ Church with the Tour Guides' Travel Guides'.",
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu9N78w9bPgtm-dScoEq_iAOgitmYT2sjlQ6mkEKuw=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Tour Guides Travel Guides',
#   'duration': '21:48',
#   'regdate_ment': '6년 전',
#   'viewCount_raw': '조회수 2.2만회'},
#  {'cd_idx': 3193042,
#   'bd_youtube_search_ko': 'Enjoy the masterpiece of the Renaissance, Duomo di Firenze',
#   'link': 'https://www.youtube.com/watch?v=sm_m3F15_OE',
#   'title': 'Florence, Italy: Famous Dome and Bronze Doors - Rick Steves’ Europe Travel Guide - Travel Bite',
#   'text': "Florence's landmark Duomo (cathedral) is crowned by Brunelleschi's majestic dome — the first Renaissance dome and the model\xa0...",
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu-6tRyjAmS2qEJFFCAQDOjvfFKPNGMs74UHJRs3Dg=s68-c-k-c0x00ffffff-no-rj',
#   'name': "Rick Steves' Europe",
#   'duration': '3:38',
#   'regdate_ment': '9년 전',
#   'viewCount_raw': '조회수 14만회'},
#  {'cd_idx': 3193042,
#   'bd_youtube_search_ko': 'Enjoy the masterpiece of the Renaissance, Duomo di Firenze',
#   'link': 'https://www.youtube.com/watch?v=Ut-e40u3lS0',
#   'title': 'Florence: Heart of the Renaissance',
#   'text': "Rick Steves' Europe Travel Guide | Fifteenth-century Florence was the home of the Renaissance and the birthplace of our modern\xa0...",
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu-6tRyjAmS2qEJFFCAQDOjvfFKPNGMs74UHJRs3Dg=s68-c-k-c0x00ffffff-no-rj',
#   'name': "Rick Steves' Europe",
#   'duration': '24:58',
#   'regdate_ment': '8년 전',
#   'viewCount_raw': '조회수 148만회'},
#  {'cd_idx': 3193042,
#   'bd_youtube_search_ko': 'Enjoy the masterpiece of the Renaissance, Duomo di Firenze',
#   'link': 'https://www.youtube.com/watch?v=MI_kR8eWsYo',
#   'title': 'FLORENCE, ITALY-THE ITALIAN RENAISSANCE LIVES ON!',
#   'text': 'Florence is one of the most beautiful cities in the world. The Renaissance was born here and it still lives on today as evidenced by\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu-Q6NEOq7aCnB5U7yG9VeceOPaihMaDXARwhPl-ng=s68-c-k-c0x00ffffff-no-rj',
#   'name': "Andy's Awesome Adventures",
#   'duration': '2:03:22',
#   'regdate_ment': '3년 전',
#   'viewCount_raw': '조회수 9.6천회'},
#  {'cd_idx': 3193042,
#   'bd_youtube_search_ko': 'Enjoy the masterpiece of the Renaissance, Duomo di Firenze',
#   'link': 'https://www.youtube.com/watch?v=9bxOwS8LsTM',
#   'title': 'Florence The City Of Renaissance - Florence Video Guide',
#   'text': 'Florence was a centre of medieval European trade and finance and one of the wealthiest cities of that era. It is considered the\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu_VmWtUcZfsgUPMaWT_AFAELfi5gmZEjV4TACG3=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Travel And Discover',
#   'duration': '39:00',
#   'regdate_ment': '4년 전',
#   'viewCount_raw': '조회수 11만회'},
#  {'cd_idx': 3193042,
#   'bd_youtube_search_ko': 'Enjoy the masterpiece of the Renaissance, Duomo di Firenze',
#   'link': 'https://www.youtube.com/watch?v=_IOPlGPQPuM',
#   'title': "How an Amateur Built the World's Biggest Dome",
#   'text': 'In 1418, Filippo Brunelleschi was tasked with building the largest dome ever seen at the time. He had no formal architecture\xa0...',
#   'image': 'https://yt3.ggpht.com/13FpK4FfJb_I-aTMNRQTmaxLO2vjEi_NzWm1KxOzr-vjYLX7QmfHwn6XC3PfEf4Oay5WjP0CXw=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'National Geographic',
#   'duration': '3:50',
#   'regdate_ment': '8년 전',
#   'viewCount_raw': '조회수 230만회'},
#  {'cd_idx': 3193042,
#   'bd_youtube_search_ko': 'Enjoy the masterpiece of the Renaissance, Duomo di Firenze',
#   'link': 'https://www.youtube.com/watch?v=Dt_6rhLVgwo',
#   'title': "The Apex of High Renaissance, Raphael Sanzio's The School of Athens | Behind the Masterpiece",
#   'text': 'Raphael Sanzio was one of the top three masters of the high renaissance, along with Leonardo da Vinci and Michelangelo.',
#   'image': 'https://yt3.ggpht.com/WNdkfI56ix0kgMYUzM-ycBd5R84SW-R0FBGPAuRyOcu-ewCS289up-wwMLvggRuRX8T7L_pr3w=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Behind the Masterpiece',
#   'duration': '11:55',
#   'regdate_ment': '10개월 전',
#   'viewCount_raw': '조회수 2.8천회'},
#  {'cd_idx': 3193042,
#   'bd_youtube_search_ko': 'Enjoy the masterpiece of the Renaissance, Duomo di Firenze',
#   'link': 'https://www.youtube.com/watch?v=6y_eL_0sQQw',
#   'title': 'History Summarized: Florence',
#   'text': "Can't start a Renaissance without building a few *Domes*. — You've seen the memes, now learn the history behind the\xa0...",
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu-Evv_YVYi9P9myaZdo8CQVQWAfy16opdwj0iQw=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Overly Sarcastic Productions',
#   'duration': '13:56',
#   'regdate_ment': '3년 전',
#   'viewCount_raw': '조회수 57만회'},
#  {'cd_idx': 3193042,
#   'bd_youtube_search_ko': 'Enjoy the masterpiece of the Renaissance, Duomo di Firenze',
#   'link': 'https://www.youtube.com/watch?v=KgNCNN4fWKA',
#   'title': '7 Masterpieces Not to Miss at the Uffizi Gallery',
#   'text': 'Calling all art lovers! Located in the heart of Florence, the Uffizi Gallery is filled with artwork from renown Italian Renaissance\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu9p2OilEabSGRydMOKBINY2gGsuTf90swt79Gc18g=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'The Tour Guy',
#   'duration': '10:11',
#   'regdate_ment': '2년 전',
#   'viewCount_raw': '조회수 2.4만회'},
#  {'cd_idx': 3193042,
#   'bd_youtube_search_ko': 'Enjoy the masterpiece of the Renaissance, Duomo di Firenze',
#   'link': 'https://www.youtube.com/watch?v=OZPnFL4e6Ik',
#   'title': 'Duomo (Cathedral) Complex -- Florence Art Tour #studyabroad #renaissance',
#   'text': 'A summary of the art and visiting options around the Duomo complex. My favorite Florence Guide Book: Rick Steves Florence\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu-3Y_A_8t4bOH0u1elStaEG3LdEVC4pNcqO7Vue=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Art History Basix',
#   'duration': '18:29',
#   'regdate_ment': '5개월 전',
#   'viewCount_raw': '조회수 330회'},
#  {'cd_idx': 3193042,
#   'bd_youtube_search_ko': 'Enjoy the masterpiece of the Renaissance, Duomo di Firenze',
#   'link': 'https://www.youtube.com/watch?v=9QXtGY_do8E',
#   'title': 'Duomo in Florence Story | Principles of Excellence #6 — Hard Work in Art',
#   'text': 'The importance of hard work is highlighted through the story of the Renaissance artist, architect, and engineer, Filippo\xa0...',
#   'image': 'https://yt3.ggpht.com/ytc/AMLnZu8Q8IGOIusVLs3PCE14lGAoewj05QwHnjgbVRiHFiI=s68-c-k-c0x00ffffff-no-rj',
#   'name': 'Rainforest Art Project',
#   'duration': '8:53',
#   'regdate_ment': '2년 전',
#   'viewCount_raw': '조회수 1.1천회'}]

# %%
columns = [
    'cd_idx', 'bd_youtube_search_ko', 'link', 'title',
    'text', 'image', 'name',  'duration', 'regdate_ment', 'viewCount','viewCount_raw','ko_youtube'] 
result_df = pd.DataFrame(data_list, columns=columns)

# %%
result_df
# Out:
#      cd_idx                               bd_youtube_search_ko  \
# 0   3193035  Take a walk in Harry Potter's magician street,...
# 1   3193035  Take a walk in Harry Potter's magician street,...
# 2   3193035  Take a walk in Harry Potter's magician street,...
# 3   3193035  Take a walk in Harry Potter's magician street,...
# 4   3193035  Take a walk in Harry Potter's magician street,...
# ..      ...                                                ...
# 65  3193042  Enjoy the masterpiece of the Renaissance, Duom...
# 66  3193042  Enjoy the masterpiece of the Renaissance, Duom...
# 67  3193042  Enjoy the masterpiece of the Renaissance, Duom...
# 68  3193042  Enjoy the masterpiece of the Renaissance, Duom...
# 69  3193042  Enjoy the masterpiece of the Renaissance, Duom...
#
#                                            link  \
# 0   https://www.youtube.com/watch?v=PjgJZCKaVdI
# 1   https://www.youtube.com/watch?v=1LUNshGrLrk
# 2    https://www.youtube.com/shorts/UbkLZ-9GZTs
# 3   https://www.youtube.com/watch?v=hBZAv-a7crQ
# 4   https://www.youtube.com/watch?v=vMooEWFeerM
# ..                                          ...
# 65  https://www.youtube.com/watch?v=Dt_6rhLVgwo
# 66  https://www.youtube.com/watch?v=6y_eL_0sQQw
# 67  https://www.youtube.com/watch?v=KgNCNN4fWKA
# 68  https://www.youtube.com/watch?v=OZPnFL4e6Ik
# 69  https://www.youtube.com/watch?v=9QXtGY_do8E
#
#                                                 title  \
# 0   Harry Potter and the Sorcerer's Stone (2001) -...
# 1   Diagon Alley (Relaxing Walk) Universal Studios...
# 2   Harry Potter Shop in Edinburgh, Victoria Stree...
# 3   Harry Potter London Magic Walking Tour and Fil...
# 4   Argh so bright, mah eyes! Weasley's Wizard Whe...
# ..                                                ...
# 65  The Apex of High Renaissance, Raphael Sanzio's...
# 66                       History Summarized: Florence
# 67   7 Masterpieces Not to Miss at the Uffizi Gallery
# 68  Duomo (Cathedral) Complex -- Florence Art Tour...
# 69  Duomo in Florence Story | Principles of Excell...
#
#                                                  text  \
# 0   FILM DESCRIPTION: Harry Potter and the Sorcere...
# 1   Welcome back to Universal Studios in Orlando, ...
# 2   According to Google maps Victoria Street is th...
# 3   Harry Potter London Magic Walking Tour and Fil...
# 4   Do orange and purple go together? I'm not exac...
# ..                                                ...
# 65  Raphael Sanzio was one of the top three master...
# 66  Can't start a Renaissance without building a f...
# 67  Calling all art lovers! Located in the heart o...
# 68  A summary of the art and visiting options arou...
# 69  The importance of hard work is highlighted thr...
#
#                                                 image  \
# 0   https://yt3.ggpht.com/LNf91hjJUCURqg2pNOKEot-Q...
# 1   https://yt3.ggpht.com/ytc/AMLnZu-Qg7t6zytsMh9i...
# 2   https://yt3.ggpht.com/wh4dP5GPIN84g0ncbf6K3bI1...
# 3   https://yt3.ggpht.com/ytc/AMLnZu--dQUjg1hNaCvp...
# 4   https://yt3.ggpht.com/-ERITRszY8GZcyVpv4f_0fx1...
# ..                                                ...
# 65  https://yt3.ggpht.com/WNdkfI56ix0kgMYUzM-ycBd5...
# 66  https://yt3.ggpht.com/ytc/AMLnZu-Evv_YVYi9P9my...
# 67  https://yt3.ggpht.com/ytc/AMLnZu9p2OilEabSGRyd...
# 68  https://yt3.ggpht.com/ytc/AMLnZu-3Y_A_8t4bOH0u...
# 69  https://yt3.ggpht.com/ytc/AMLnZu8Q8IGOIusVLs3P...
#
#                                                  name duration regdate_ment  \
# 0                                 Harry Potter Things     3:39         1년 전
# 1                                    Theme Park Shark     9:08         2년 전
# 2                                   Rhona The Unicorn   SHORTS         2주 전
# 3   Joolz Guides - London History Walks - Travel F...    17:25         5년 전
# 4                                             ellieV     30:15         2년 전
# ..                                                ...      ...          ...
# 65                             Behind the Masterpiece    11:55       10개월 전
# 66                       Overly Sarcastic Productions    13:56         3년 전
# 67                                       The Tour Guy    10:11         2년 전
# 68                                  Art History Basix    18:29        5개월 전
# 69                             Rainforest Art Project     8:53         2년 전
#
#     viewCount viewCount_raw  ko_youtube
# 0         NaN     조회수 4.3만회         NaN
# 1         NaN     조회수 9.1만회         NaN
# 2         NaN     조회수 1.2천회         NaN
# 3         NaN      조회수 97만회         NaN
# 4         NaN      조회수 88만회         NaN
# ..        ...           ...         ...
# 65        NaN     조회수 2.8천회         NaN
# 66        NaN      조회수 57만회         NaN
# 67        NaN     조회수 2.4만회         NaN
# 68        NaN      조회수 330회         NaN
# 69        NaN     조회수 1.1천회         NaN
#
# [70 rows x 12 columns]

# %%
result_df = pd.DataFrame(data_list, columns=columns)
result_df

# %%
result_df
# Out:
#        cd_idx                               bd_youtube_search_ko  \
# 0     3193035  Take a walk in Harry Potter's magician street,...
# 1     3193035  Take a walk in Harry Potter's magician street,...
# 2     3193035  Take a walk in Harry Potter's magician street,...
# 3     3193035  Take a walk in Harry Potter's magician street,...
# 4     3193035  Take a walk in Harry Potter's magician street,...
# ...       ...                                                ...
# 7250        ↵  판단 잎으로 만드는 달콤함과 고소함의 결정체, 카야잼을 아시나요? 싱가포르의 '야쿤...
# 7251        ↵  판단 잎으로 만드는 달콤함과 고소함의 결정체, 카야잼을 아시나요? 싱가포르의 '야쿤...
# 7252        ↵  판단 잎으로 만드는 달콤함과 고소함의 결정체, 카야잼을 아시나요? 싱가포르의 '야쿤...
# 7253        ↵  판단 잎으로 만드는 달콤함과 고소함의 결정체, 카야잼을 아시나요? 싱가포르의 '야쿤...
# 7254        ↵  판단 잎으로 만드는 달콤함과 고소함의 결정체, 카야잼을 아시나요? 싱가포르의 '야쿤...
#
#                                              link  \
# 0     https://www.youtube.com/watch?v=PjgJZCKaVdI
# 1     https://www.youtube.com/watch?v=0g1PPDlKZlU
# 2     https://www.youtube.com/watch?v=QobZIsKd-68
# 3     https://www.youtube.com/watch?v=ZBSpbtVLObc
# 4     https://www.youtube.com/watch?v=wXh1ae8zOr0
# ...                                           ...
# 7250  https://www.youtube.com/watch?v=obvBZlP5FMg
# 7251  https://www.youtube.com/watch?v=0WTPw0-15k4
# 7252  https://www.youtube.com/watch?v=WiQ36gtNVyA
# 7253  https://www.youtube.com/watch?v=4FxxsGsgwww
# 7254  https://www.youtube.com/watch?v=or1LUqCj6yk
#
#                                                   title  \
# 0     Harry Potter and the Sorcerer's Stone (2001) -...
# 1     Top 6 Diagon Alley Hidden Gems | Secrets of Di...
# 2     Diagon Alley | Harry Potter Inspired Music | A...
# 3     Diagon Alley at Leadenhall Market London, Harr...
# 4                           Take part in Walk with Joe!
# ...                                                 ...
# 7250  🅾️다진생강.다진마늘 냉동하기(초코볼 담는 플라스틱통 활용하기) [How to Fr...
# 7251  수정과의 단짝! 달달, 쫀득, 고소한 ‘곶감쌈’만들기/ 干し柿のくるみ巻き/ Gotg...
# 7252  집밥숨선생으로 거듭나기💫 / 운동하고 밥먹고 / 대구 수목원 / 빠다롤더테라스 / ...
# 7253  [모의고사] 식물 분류 동정 (14) / 피자식물(목본) 20종 / #청미래덩굴과#...
# 7254  #49 [매일패턴] 패턴으로 배우는 영어표현/ Don't you have to te...
#
#                                                    text  \
# 0     FILM DESCRIPTION: Harry Potter and the Sorcere...
# 1     The best of Diagon Alley, let's explore the to...
# 2     Take a trip down Diagon Alley with beautiful m...
# 3     Diagon Alley is one of many important location...
# 4     Join in with Joe Wicks and Walk with Joe this ...
# ...                                                 ...
# 7250  다진생강.다진마늘 냉동하기(초코볼 담는 플라스틱통 활용하기) [How to Free...
# 7251  구독&좋아요 부탁드려요(_ _) 감사합니다! 수정과의 단짝! '곶감쌈'을 만들어 보...
# 7252  5일간의 일상입니다♪ *BGM - Music by carego - Little Ch...
# 7253  생물분류기사 #생물분류 #식물분류 #생물 #식물 #피자식물 #속씨식물 #청미래덩굴과...
# 7254  이제 출발해야 되지 않니? Don't you have to leave now? 가라...
#
#                                                   image                  name  \
# 0     https://i.ytimg.com/vi/PjgJZCKaVdI/hq720.jpg?s...   Harry Potter Things
# 1     https://i.ytimg.com/vi/0g1PPDlKZlU/hq720.jpg?s...              Rix Flix
# 2     https://i.ytimg.com/vi/QobZIsKd-68/hq720.jpg?s...   Ambient Soundscapes
# 3     https://i.ytimg.com/vi/ZBSpbtVLObc/hq720.jpg?s...       KEEP WALKING 4K
# 4     https://i.ytimg.com/vi/wXh1ae8zOr0/hq720.jpg?s...  BBC Children in Need
# ...                                                 ...                   ...
# 7250  https://i.ytimg.com/vi/obvBZlP5FMg/hq720.jpg?s...               soi소이할미
# 7251  https://i.ytimg.com/vi/0WTPw0-15k4/hq720.jpg?s...         장보심 jangbosim
# 7252  https://i.ytimg.com/vi/WiQ36gtNVyA/hqdefault.j...     프롬숨숨 From Sumsumm
# 7253  https://i.ytimg.com/vi/4FxxsGsgwww/hqdefault.j...        은재맘 ' 나무 공부방 '
# 7254  https://i.ytimg.com/vi/or1LUqCj6yk/hqdefault.j...            참쉬운사다리5분영어
#
#      duration  regdate_ment  viewCount  viewCount_raw  ko_youtube
# 0        3:39           NaN        NaN            NaN         NaN
# 1       10:32           NaN        NaN            NaN         NaN
# 2     1:00:01           NaN        NaN            NaN         NaN
# 3        8:03           NaN        NaN            NaN         NaN
# 4        1:02           NaN        NaN            NaN         NaN
# ...       ...           ...        ...            ...         ...
# 7250     3:32           NaN        NaN            NaN         NaN
# 7251     4:30           NaN        NaN            NaN         NaN
# 7252    15:51           NaN        NaN            NaN         NaN
# 7253     7:02           NaN        NaN            NaN         NaN
# 7254     5:36           NaN        NaN            NaN         NaN
#
# [7255 rows x 12 columns]

# %% [markdown]
# # 3. 최종 데이터 정제 저장

# %%
# 임시 백업 df 설정
temp_df = pd.DataFrame(data_list, columns=columns)

# 결측값 있는 행 확인
check_columns  = ["cd_idx", "bd_youtube_search_ko", "link", "title", "image", "name"]
missing_values = result_df[result_df[check_columns].isnull().any(axis=1)]

print(len(temp_df))
print(len(missing_values))
print(len(temp_df) - len(missing_values))
# Out:
# 7255
# 23
# 7232

# %%
# 결측값 있는 행 drop 및 저장
result_df.drop(missing_values.index, axis=0, inplace=True)
print(f"1차 drop 이후 개수: {len(result_df)}")

# 추가 요청 사항 drop 및 저장
drop_df    = result_df[(result_df["duration"].isnull() == True) | (result_df["regdate_ment"].isnull() == True)]
drop_index = drop_df.index
result_df.drop(drop_index, axis=0, inplace=True)
print(f"추가 drop 개수: {len(drop_index)}")

# index 정렬
result_df.reset_index(drop=True, inplace=True)
print(len(result_df))
# Out:
# 1차 drop 이후 개수: 7232
# 추가 drop 개수: 7232
# 0

# %% [markdown]
# # 4.나머지 정보 채우기 -viewCount

# %%
for idx in tqdm(range(len(result_df))): 
    raw=result_df['viewCount_raw'][idx].replace(' views','')
    if 'K' in raw:
        raw=float(raw.replace('K',''))*1000
    elif 'M' in raw:
        raw=float(raw.replace('M',''))*1000000
    elif 'B' in raw:
        raw=float(raw.replace('B',''))*1000000000
    
    elif 'No' in raw:
        raw=0
    elif 'view' in raw:
        raw=result_df['viewCount_raw'][idx].replace(' view','')
    raw=int(raw)
    result_df['viewCount'][idx]=raw
    print(raw,type(raw))
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# # excel 파일로 저장

# %%
Desktop
# Out:
# '/Users/mycelebs/Desktop/staypia_데이터수집'

# %%
result_df.to_csv(f"{Desktop}/youtube/csv_result/youtube_crawling_bucketlist_" + datetime.datetime.now().strftime('%y%m%d') +"-en.csv")
