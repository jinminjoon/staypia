# %%
import pandas as pd
import numpy as np
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import time
import datetime
from datetime import datetime
from sqlalchemy import create_engine
from tqdm import tqdm
import pymysql
import os

import warnings
warnings.filterwarnings('ignore')

# %%
path = os.getcwd()
path
# Out:
# '/Users/mycelebs/Desktop/staypia_데이터수집'

# %%
# 파일 날짜 확인 후 수정해주기
youtube_city_df = pd.read_csv(f'{path}/youtube/csv_result/youtube_crawling_city_221201.csv')
youtube_bucket_df = pd.read_csv(f'{path}/youtube/csv_result/youtube_crawling_bucketlist_221128-en.csv')
google_keyword_df = pd.read_excel(f'{path}/google_keyword_result/google_keywords_crawling_221128-final.xlsx')

# %%
youtube_city_df['regist_date'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
youtube_city_df['update_date'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

youtube_city_df = youtube_city_df[['cd_idx',
                                   'cd_youtube_search_ko',
                                   'link',
                                   'title',
                                   'text',
                                   'image',
                                   'name',
                                   'duration',
                                   'regdate_ment',
                                   'viewCount',
                                   'viewCount_raw',
                                   'regist_date',
                                   'update_date'
                                  ]]

youtube_city_df
# Out:
#         cd_idx          cd_youtube_search_ko  \
# 0      3179591  Czech Republic Lhotka travel
# 1      3179591  Czech Republic Lhotka travel
# 2      3179591  Czech Republic Lhotka travel
# 3      3179591  Czech Republic Lhotka travel
# 4      3179591  Czech Republic Lhotka travel
# ...        ...                           ...
# 55967  3179206   Philippines Hinatuan travel
# 55968  3179206   Philippines Hinatuan travel
# 55969  3179206   Philippines Hinatuan travel
# 55970  3179206   Philippines Hinatuan travel
# 55971  3179206   Philippines Hinatuan travel
#
#                                               link  \
# 0      https://www.youtube.com/watch?v=OkyWd9rFhg8
# 1      https://www.youtube.com/watch?v=ErbOZlSukzg
# 2      https://www.youtube.com/watch?v=BFKzX7u-3yg
# 3      https://www.youtube.com/watch?v=psdnunCXSxY
# 4      https://www.youtube.com/watch?v=rW_7ZHfZOSs
# ...                                            ...
# 55967  https://www.youtube.com/watch?v=QIMTFvNhiR0
# ...

# %%
youtube_bucket_df['regist_date'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
youtube_bucket_df['update_date'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

youtube_bucket_df = youtube_bucket_df[['cd_idx',
                                       'bd_youtube_search_ko',
                                       'link',
                                       'title',
                                       'text',
                                       'image',
                                       'name',
                                       'duration',
                                       'regdate_ment',
                                       'viewCount',
                                       'viewCount_raw',
                                       'regist_date',
                                       'update_date'
                                      ]]
youtube_bucket_df
# Out:
#        cd_idx                               bd_youtube_search_ko  \
# 0     3193035  Take a walk in Harry Potter's magician street,...
# 1     3193035  Take a walk in Harry Potter's magician street,...
# 2     3193035  Take a walk in Harry Potter's magician street,...
# 3     3193035  Take a walk in Harry Potter's magician street,...
# 4     3193035  Take a walk in Harry Potter's magician street,...
# ...       ...                                                ...
# 7049        ↵  판단 잎으로 만드는 달콤함과 고소함의 결정체, 카야잼을 아시나요? 싱가포르의 '야쿤...
# 7050        ↵  판단 잎으로 만드는 달콤함과 고소함의 결정체, 카야잼을 아시나요? 싱가포르의 '야쿤...
# 7051        ↵  판단 잎으로 만드는 달콤함과 고소함의 결정체, 카야잼을 아시나요? 싱가포르의 '야쿤...
# 7052        ↵  판단 잎으로 만드는 달콤함과 고소함의 결정체, 카야잼을 아시나요? 싱가포르의 '야쿤...
# 7053        ↵  판단 잎으로 만드는 달콤함과 고소함의 결정체, 카야잼을 아시나요? 싱가포르의 '야쿤...
#
#                                              link  \
# 0     https://www.youtube.com/watch?v=PjgJZCKaVdI
# 1     https://www.youtube.com/watch?v=2WWLBIUdxOw
# ...

# %%
google_keyword_df['tcc_idx'] = 1002
google_keyword_df['regist_date'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

google_keyword_df = google_keyword_df[['tcc_idx',
                                       'cd_idx',
                                       'keywords',
                                       'words_length',
                                       'regist_date'
                                      ]]

google_keyword_df
# Out:
#       tcc_idx   cd_idx                                           keywords  \
# 0        1002  3179591  where is czech republic, can i travel to czech...
# 1        1002  3179532  bulgaria map, sofia sofia bulgaria, bulgaria l...
# 2        1002  3176579  when is next world cup, qatar world cup 2022, ...
# 3        1002  3174718                      philippines travel, cebu city
# 4        1002  3166441                                               None
# ...       ...      ...                                                ...
# 5595     1002  3178218                      prudhoe uk, hexham population
# 5596     1002  3178587                                               None
# 5597     1002  3178842  blanchisseuse beach house for rent trinidad, b...
# 5598     1002  3178916  czech republic coronavirus travel restrictions...
# 5599     1002  3179206  surigao tourist spots, surigao del sur tourist...
#
#       words_length          regist_date
# ...

# %%
# name = 'yooj'
# password = 'tei0609!'
# today = datetime.now().strftime('%Y%m%d')

# try: 
#     db_connection_str = f'mysql+pymysql://{name}:{password}@db.ds.mycelebs.com/staypia'
#     db_connection = create_engine(db_connection_str)
#     conn = db_connection.connect()
    
#     sql = f"""RENAME TABLE city_youtube_info TO city_youtube_info{today},
#              bucket_youtube_info TO bucket_youtube_info{today},
#              related_keywords_module TO related_keywords_module{today};"""
    
#     conn.close()
# except Exception as e:
#     conn.close()
#     print(e)

# %%
try: 
    db_connection_str = f'mysql+pymysql://{name}:{password}@db.ds.mycelebs.com/staypia'
    db_connection = create_engine(db_connection_str)
    conn = db_connection.connect()

    youtube_city_df.to_sql(name = f'city_youtube_info', if_exists = 'append', con = db_connection, index = False)  
    conn.close()
except Exception as e:
    conn.close()
    print(e)

# %%
try: 
    db_connection_str = f'mysql+pymysql://{name}:{password}@db.ds.mycelebs.com/staypia'
    db_connection = create_engine(db_connection_str)
    conn = db_connection.connect()

    youtube_bucket_df.to_sql(name = f'bucket_youtube_info', if_exists = 'append', con = db_connection, index = False)  
    conn.close()
except Exception as e:
    conn.close()
    print(e)

# %%
try: 
    db_connection_str = f'mysql+pymysql://{name}:{password}@db.ds.mycelebs.com/staypia'
    db_connection = create_engine(db_connection_str)
    conn = db_connection.connect()

    google_keyword_df.to_sql(name = f'related_keywords_module', if_exists = 'append', con = db_connection, index = False)  
    conn.close()
except Exception as e:
    conn.close()
    print(e)

# %% [markdown]
# # 완료 후 필수적으로 백업 파일 만들기!
